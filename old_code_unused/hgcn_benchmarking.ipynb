# %%
from age_predictor import Age_Predictor

nn_predictor = Age_Predictor("2023_9_23", "0", "neural_network")
nn_predictor.regression()
# Out:
# Using Log Path : logs\lp\2023_9_23\0
# Projecting Train Embeddings :
# 100%|███████████████████████████████████████████████████████████████████████████████| 527/527 [00:01<00:00, 310.22it/s]
# Scaling Projected Train Embeddings :
# Epoch [100 / 1000]; Loss : 18.8502
# Epoch [200 / 1000]; Loss : 0.7511
# Epoch [300 / 1000]; Loss : 0.0665
# Epoch [400 / 1000]; Loss : 0.0088
# Epoch [500 / 1000]; Loss : 0.0132
# Epoch [600 / 1000]; Loss : 0.0003
# Epoch [700 / 1000]; Loss : 0.0001
# Epoch [800 / 1000]; Loss : 0.0000
# Epoch [900 / 1000]; Loss : 0.0000
# Epoch [1000 / 1000]; Loss : 0.0000
# Projecting Test Embeddings :
# 100%|█████████████████████████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 224.06it/s]
# Scaling Projected Test Embeddings :
# ...

# %%
import os
os.environ['DATAPATH'] = os.path.join(os.getcwd(), 'data')
os.environ['LOG_DIR'] = os.path.join(os.getcwd(), 'logs')
    
! python train_graph_iteration.py \
    --task lp \
    --act None \
    --dataset cam_can_multiple\
    --model HGCN \
    --threshold 0.3598 \
    --lr 0.025 \
    --dim 3 \
    --num-layers 2 \
    --bias 1 \
    --dropout 0.25 \
    --weight-decay 1e-3 \
    --manifold Hyperboloid \
    --log-freq 5 \
    --cuda -1 \
    --patience 500 \
    --grad-clip 0.1 \
    --seed 1234 \
    --save 1

# ! python train_graph_iteration.py \
#     --task lp \
#     --act None \
#     --dataset cam_can_multiple\
#     --model HyperGCN \
#     --threshold 0.3598 \
#     --lr 0.025 \
#     --dim 3 \
#     --num-layers 2 \
#     --bias 1 \
#     --dropout 0.25 \
#     --weight-decay 1e-3 \
#     --manifold Hyperboloid \ # THIS SHOULD BE CHANGED ABOVE!!!
#     --log-freq 5 \
#     --cuda -1 \
#     --patience 500 \
#     --grad-clip 0.1 \
#     --seed 1234 \
#     --save 1
